# %%
import pandas as pd

# %%
veri=pd.read_csv("ugurfilm3.txt")

# %%
veri
# Out:
#                                                   İSİM        SÜRE   YIL  \
# 0                           Systemsprenger – Oyunbozan  125 Dakika  2019
# 1                                     Seules Les Bêtes  117 Dakika  2019
# 2                       The Unforgivable – Affedilemez  112 Dakika  2021
# 3            Quo Vadis Aida? – Nereye Gidiyorsun Aida?  101 Dakika  2020
# 4                                                Yanco   85 Dakika  1961
# ...                                                ...         ...   ...
# 9928                              Sinema Bir Mucizedir  103 Dakika  2005
# 9929                                  Chronic – Kronik   93 Dakika  2015
# 9930  Juste La Fin Du Monde – Alt Tarafı Dünyanın Sonu   97 Dakika  2016
# 9931                                      Mary and Max   92 Dakika  2009
# 9932                       Busanhaeng – Zombi Ekspresi  118 Dakika  2016
#
#                                                    ÜLKE           YÖNETMEN  \
# ...

# %%
Yonetmen = veri.groupby('YÖNETMEN')

# %%
Yonetmen.sum()
# Out:
#                                                                    İSİM  \
# YÖNETMEN
# -                     BBC – Vatican – The Hidden World – Vatikan Giz...
# A. Edward Sutherland                                 Murders in the Zoo
# Aamir Khan                         Taare Zameen Par – Her Çocuk Özeldir
# Aanand Rai                                       Tanu Weds Manu Returns
# Aaron Burns                                                       Madre
# ...                                                                 ...
# İsmet Eraydın                                         Tepe’nin Uşakları
# Łukasz Palkowski                                       NajlepszyBogowie
# Şahin Gök             Şahane EvlilikEskici ve OğullarıSon CellatMele...
# Şerif Gören                               YolYılanların ÖcüPiyade Osman
# Šarūnas Bartas        Septyni Nematomi ZmonesA Casa – EvIndigène d’E...
#
#                                                                    SÜRE  \
# YÖNETMEN
# ...
